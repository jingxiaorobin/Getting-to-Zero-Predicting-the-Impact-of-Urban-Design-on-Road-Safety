# %%
#!pip install geopandas

# %%
#!conda install rtree

# %%
#!pip install osmnx

# %%
#Run Locally
import pandas as pd
import numpy as np
import geopandas as gpd
import os
import rtree
import osmnx
import shapely
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
from fiona.crs import from_epsg
import shapely
# %matplotlib inline
#from google.colab import drive

#drive.mount('/content/drive/')

# %% [markdown]
# # Sidewalk + sdwkothrs

# %%
#os.listdir('/content/drive/My Drive/Getting to Zero Capstone /Data') #google drive
os.listdir()
# Out:
# ['joined_plazasq.csv',
#  'joined_beach.csv',
#  'Data Augmentation and Preprocessing objectives.docx',
#  'CEA-33.pdf',
#  'joined_pubgardn.csv',
#  'Quantitative Theoretical and Conceptual Framework Use in Agricultural Education Research.pdf',
#  'joined_sidewalk+othrsdwk.csv',
#  '.DS_Store',
#  'Deliverable 2.docx',
#  'USI_II_Summer_2019_syllabus_V05_15_19.pdf',
#  'Untitled.ipynb',
#  'ToWalkOrNotToWalk.pdf',
#  'Shapefiles',
#  '04oct-Article-AET.pdf',
#  'joined_planimetric.csv',
#  'Data_planimetrics.ipynb',
#  'NYUSampleHotspotsVsControlProcessedData20190625.xlsx',
#  'joined_playsprt_swimpool.csv',
#  'joined_driveway.csv',
#  'NYU_capstone_VML',
#  'joined_median.csv',
#  'joined_parkplay.csv',
#  'joined_playsprt_baseball.csv',
#  'segs_275.csv',
#  'joined_playsprt_football.csv',
#  'Variable analysis-Robin.ipynb',
#  'citiessaferbydesign_final.pdf',
#  'joined_parkinglot_2000.csv',
#  '.ipynb_checkpoints',
#  'googleapi.py',
#  'safe_streets_--_green_cities-_good_health.pdf',
#  'joined_pbspothr.csv',
#  'data',
#  'joined_abndbldg.csv',
#  'prepocessingforMerge.ipynb']

# %%
#Change Path before reproduce
#path1 = '/content/drive/My Drive/Getting to Zero Capstone /Data/planimetric/Shapefiles' # google path to dataset requiring merged
#path2 = '/content/drive/My Drive/Getting to Zero Capstone /Data/dataJoin/sampleArea' # google path to main dataset

path1 = 'Shapefiles/Sidewalk.shp' # path to dataset requiring merged
path2 = 'data/road_network_data/osm/osm_w_collisions/edges/edges.shp'# path to sample area
path3 = 'data/road_network_data/osm/osm_w_collisions/nodes/nodes.shp'

segs = gpd.read_file(path2).to_crs({'init': 'epsg:2263'})
#segs.crs = {'init': 'epsg:2263'}
#segs = segs.to_crs({'init': 'epsg:2263'})
nodes = gpd.read_file(path3).to_crs({'init': 'epsg:2263'})

# %%
segs.head(1)
# Out:
#   access bridge      from      highway junction key lanes  length maxspeed  \
# 0   None   None  42817478  residential     None   0  None  81.315   20 mph
#
#           name  ... FIRST_Traf MAX_Number MAX_Numb_1 MAX_Numb_2 MAX_POSTED  \
# 0  47th Avenue  ...          T          2          2          4         25
#
#   FIRST_Bike FIRST_Stre  MAX_Street MIN_Street  \
# 0          3  47 AVENUE        45.0       45.0
#
#                                             geometry
# 0  LINESTRING (1001015.644995337 210168.626706699...
#
# [1 rows x 30 columns]

# %%
#nodes.head(1)

# %%
segs.columns
# Out:
# Index(['access', 'bridge', 'from', 'highway', 'junction', 'key', 'lanes',
#        'length', 'maxspeed', 'name', 'oneway', 'osmid', 'ref', 'service', 'to',
#        'tunnel', 'width', 'id', 'LBlockFace', 'RBlockFace', 'FIRST_Traf',
#        'MAX_Number', 'MAX_Numb_1', 'MAX_Numb_2', 'MAX_POSTED', 'FIRST_Bike',
#        'FIRST_Stre', 'MAX_Street', 'MIN_Street', 'geometry'],
#       dtype='object')

# %%
segs = segs[['id','geometry']]
segs
# Out:
#           id                                           geometry
# 0          1  LINESTRING (1001015.644995337 210168.626706699...
# 1          2  LINESTRING (1000385.279703911 210279.867242070...
# 2          3  LINESTRING (1000555.397690829 209732.936517981...
# 3          4  LINESTRING (1000788.20476476 210489.0828251308...
# 4          5  LINESTRING (1002699.169230139 177417.034729413...
# 5          6  LINESTRING (1002615.212700135 178435.923287202...
# 6          7  LINESTRING (1002921.868557177 177996.413173496...
# 7          8  LINESTRING (1002383.892641102 177952.28650031,...
# 8          9  LINESTRING (1003181.006567429 178017.380318647...
# 9         10  LINESTRING (1002921.868557177 177996.413173496...
# 10        11  LINESTRING (1002968.718888581 177437.971074869...
# 11        12  LINESTRING (1003181.006567429 178017.380318647...
# 12        13  LINESTRING (1003459.565062103 178040.551535527...
# 13        14  LINESTRING (1003143.190579595 178477.861354140...
# 14        15  LINESTRING (1003738.678252722 178063.362062385...
# 15        16  LINESTRING (1003505.511456077 177482.801962808...
# 16        17  LINESTRING (1003421.740957989 178504.675417940...
# 17        18  LINESTRING (1003738.678252722 178063.362062385...
# 18        19  LINESTRING (1003998.092021141 178084.702469677...
# 19        20  LINESTRING (1003785.742364399 177503.792267497...
# 20        21  LINESTRING (1003998.092021141 178084.702469677...
# 21        22  LINESTRING (1004267.493503356 178106.782525746...
# 22        23  LINESTRING (1003959.699233469 178553.197002717...
# 23        24  LINESTRING (916125.0752615707 125040.956922107...
# 24        25  LINESTRING (916798.0721047929 125363.332576402...
# 25        26  LINESTRING (916472.7617062711 125174.786975155...
# 26        27  LINESTRING (916037.7491868632 125831.420719124...
# 27        28  LINESTRING (1004267.493503356 178106.782525746...
# 28        29  LINESTRING (1004536.062102001 178128.864873262...
# 29        30  LINESTRING (1004312.903371609 177549.034011053...
# ...      ...                                                ...
# 91636  91637  LINESTRING (983040.9269012499 158244.951136455...
# 91637  91638  LINESTRING (1048615.590141152 215123.687450611...
# 91638  91639  LINESTRING (1049423.955390021 215349.545927683...
# 91639  91640  LINESTRING (1049674.770486682 215418.351257983...
# 91640  91641  LINESTRING (1006919.272440978 179554.764706065...
# 91641  91642  LINESTRING (1006455.183934041 179158.675980994...
# 91642  91643  LINESTRING (1007161.845761728 179761.566214530...
# 91643  91644  LINESTRING (1005662.25873154 178485.4149951686...
# 91644  91645  LINESTRING (1005860.772096962 178653.181558148...
# 91645  91646  LINESTRING (1006057.060118453 178824.226709056...
# 91646  91647  LINESTRING (1041819.11142836 212758.0469581661...
# 91647  91648  LINESTRING (1042561.417252835 213010.553220396...
# 91648  91649  LINESTRING (919659.6759707149 127665.027634930...
# 91649  91650  LINESTRING (1042802.253965549 213098.937380189...
# 91650  91651  LINESTRING (918222.1944895226 126435.644355487...
# 91651  91652  LINESTRING (995501.289406143 177393.9834493627...
# 91652  91653  LINESTRING (997340.0297416071 177541.728240754...
# 91653  91654  LINESTRING (917821.0709070796 126069.496162791...
# 91654  91655  LINESTRING (1016224.635101268 209057.381561734...
# 91655  91656  LINESTRING (998142.998460675 177604.8383239318...
# 91656  91657  LINESTRING (917821.0709070796 126069.496162791...
# 91657  91658  LINESTRING (998947.0691619398 177674.169176433...
# 91658  91659  LINESTRING (999215.089918489 177700.1999932411...
# 91659  91660  LINESTRING (999472.845762895 177722.9483847415...
# 91660  91661  LINESTRING (999743.0886640575 177743.521499747...
# 91661  91662  LINESTRING (1000007.783605987 177761.179399933...
# 91662  91663  LINESTRING (1000270.81334818 177778.839085409,...
# 91663  91664  LINESTRING (1000529.955943658 177799.777964092...
# 91664  91665  LINESTRING (1001855.90362923 177908.1789688257...
# 91665  91666  LINESTRING (1002125.030723486 177931.328058303...
#
# [91666 rows x 2 columns]

# %%
#test one
sidewalks = gpd.read_file(path1).to_crs({'init': 'epsg:2263'})
sidewalks.head(2)
# Out:
#       SOURCE_ID  FEATURE_CO  SUB_FEATUR     STATUS  \
# 0  2.138000e+10        3800      380000  Unchanged
# 1  2.138000e+10        3800      380000  Unchanged
#
#                                             geometry
# 0  POLYGON ((984808.2226250023 190837.1944909841,...
# 1  POLYGON ((985043.92556566 190997.1377406418, 9...

# %%
# draw one sidewalk
sidewalks.iloc[1,4]

# %%
sidewalks.columns
# Out:
# Index(['SOURCE_ID', 'FEATURE_CO', 'SUB_FEATUR', 'STATUS', 'geometry'], dtype='object')

# %%
segs_buff = segs.copy()
segs_buff['geometry'] = segs_buff.geometry.buffer(120, cap_style=2)

#each segment can have multiple pavement

# %%
#draw sidewalk with the mideast area
sidewalks_tmp = gpd.sjoin(sidewalks, segs_buff, how  = 'left')
sidewalks_tmp = sidewalks_tmp[sidewalks_tmp['index_right'] >= 0]

# %%
sidewalks_tmp.head()
# Out:
#       SOURCE_ID  FEATURE_CO  SUB_FEATUR     STATUS  \
# 0  2.138000e+10        3800      380000  Unchanged
# 0  2.138000e+10        3800      380000  Unchanged
# 0  2.138000e+10        3800      380000  Unchanged
# 0  2.138000e+10        3800      380000  Unchanged
# 0  2.138000e+10        3800      380000  Unchanged
#
#                                             geometry  index_right       id
# 0  POLYGON ((984808.2226250023 190837.1944909841,...      24344.0  24345.0
# 0  POLYGON ((984808.2226250023 190837.1944909841,...      24337.0  24338.0
# 0  POLYGON ((984808.2226250023 190837.1944909841,...      24336.0  24337.0
# 0  POLYGON ((984808.2226250023 190837.1944909841,...      43726.0  43727.0
# 0  POLYGON ((984808.2226250023 190837.1944909841,...      43888.0  43889.0

# %%
#plot sidewalk with segment buffer
from shapely.geometry import Point, box


fig, ax = plt.subplots(figsize=(12,8))
minx, miny, maxx, maxy = (970000, 150000, 1000000, 190000)
sample_bounds = box(minx, miny, maxx, maxy)
segs_b = segs_buff[segs_buff.within(sample_bounds)]
segs_joined_sample = sidewalks_tmp[sidewalks_tmp.within(sample_bounds)]


ax.set_title('Sidewalks in Sample Area', fontsize=20)
segs_b.plot(edgecolor='grey', facecolor='lightgrey', ax= ax, lw=0.5, zorder=-1, alpha=0.4)
segs_joined_sample.plot(edgecolor='lightblue', facecolor='blue', ax= ax, lw=0.5, zorder=-1, alpha=0.4)

ax.axis('off')
# Out:
# (971242.5321470357, 1001368.7415797788, 148006.5231906999, 191994.66504222757)

# %%
#This is helpful when a single columns translates to multiple SoP variables
sidewalks_tmp = sidewalks_tmp[['SUB_FEATUR','geometry','id']].reset_index(level=0, drop=True)

# %%
sidewalks_tmp.head()
# Out:
#    SUB_FEATUR                                           geometry       id
# 0      380000  POLYGON ((984808.2226250023 190837.1944909841,...  24345.0
# 1      380000  POLYGON ((984808.2226250023 190837.1944909841,...  24338.0
# 2      380000  POLYGON ((984808.2226250023 190837.1944909841,...  24337.0
# 3      380000  POLYGON ((984808.2226250023 190837.1944909841,...  43727.0
# 4      380000  POLYGON ((984808.2226250023 190837.1944909841,...  43889.0

# %%
sidewalks_tmp[sidewalks_tmp.id ==24338.0]
#Each id may have multiple records
# Out:
#         SUB_FEATUR                                           geometry       id
# 1           380000  POLYGON ((984808.2226250023 190837.1944909841,...  24338.0
# 206016      380000  POLYGON ((984680.6648092419 190617.8816093951,...  24338.0
# 210525      380010  POLYGON ((984762.9884634912 190878.7636335641,...  24338.0

# %%
sidewalks_tmp.SUB_FEATUR.value_counts()
# Out:
# 380000    228412
# 380010     16233
# Name: SUB_FEATUR, dtype: int64

# %%
# According to the github READMe explanation: 380000 == sidewalk,380010 = interior sidewalk
transform_dict = {380000:'sidewalk',
                  380010:'othrsdwk'}


sidewalks_raw = pd.get_dummies(sidewalks_tmp['SUB_FEATUR']).rename(columns = transform_dict)
print(sidewalks_raw.shape)
sidewalks_raw.head()
# Out:
# (244645, 2)
#    sidewalk  othrsdwk
# 0         1         0
# 1         1         0
# 2         1         0
# 3         1         0
# 4         1         0

# %%
sidewalk_nyc = pd.merge(sidewalks_tmp[['id']],sidewalks_raw,left_index=True, right_index= True).groupby('id').sum()\
                .reset_index(level=0, drop=False)


sidewalk_nyc.sidewalk.value_counts()
#sidewalk_nyc.head()
# Out:
# 2      50184
# 3      19561
# 4       8926
# 1       5092
# 5       2604
# 6        916
# 0        384
# 7        354
# 8        196
# 9        118
# 10        60
# 11        45
# 12        45
# 13        31
# 14        19
# 15        18
# 16        14
# 18        11
# 17        11
# 25         8
# 21         6
# 20         5
# 19         5
# 23         5
# 28         5
# 24         3
# 30         2
# 37         2
# 35         2
# 32         2
# 31         2
# 27         2
# 26         2
# 22         2
# 61         1
# 40         1
# 44         1
# 47         1
# 55         1
# 120        1
# 63         1
# Name: sidewalk, dtype: int64

# %%
sidewalk_nyc.rename(columns = {'id':'segid'},inplace =True)
sidewalk_nyc.head()
# Out:
#    segid  sidewalk  othrsdwk
# 0    1.0         2         0
# 1    2.0         3         0
# 2    3.0         4         0
# 3    4.0         3         0
# 4    5.0         2         0

# %% [markdown]
# ### 1. Sidewalk number >2 roughly means it contains both sides of sidewalk, since the original data of sidewalk is irregular polygon. The average width of Street is 60- 100 for Manhattan, here I take 120 feet as buffer.
#
# ### 2. 384 street with 0 sidewalks. 5092 streets have 1 side of sidewalk.
#
# ### 3. Same for othrsdwk

# %%
#write the sidewalk
sidewalk_nyc.to_csv("joined_sidewalk+othrsdwk.csv",index=False,sep=',')

# %% [markdown]
# # Apply on other features -Median

# %%
for fc in os.listdir('Shapefiles'):
  if fc.endswith('.shp'):
    print(fc)
# Out:
# Elevated_railroad.shp
# Water_Elevation.shp
# Railroad_Retaining_Wall.shp
# Bridge.shp
# Interior_Sidewalk_Centerline.shp
# Median.shp
# Ventilation_grate.shp
# Tunnel.shp
# Railway_fence.shp
# Greenstreets.shp
# Building_Elevation.shp
# Beach_Shoreline.shp
# Pool.shp
# Football_Field.shp
# Baseball_Softball_Field.shp
# Recreational_area__Not_NYC_designated_parks_.shp
# Overpass.shp
# Road_Edge.shp
# Court.shp
# Open_cut_depression_railroad.shp
# Swimming_Pool.shp
# Elevated_subway_train_station.shp
# Shoreline.shp
# River.shp
# Pedestrian_Bridge.shp
# Roadbed.shp
# Plaza.shp
# Sidewalk.shp
# Embankment_railroad.shp
# Airport_Runways.shp
# Park_Boundary.shp
# Railroad_Viaduct.shp
# Toll_Area.shp
# Pier.shp
# Running_Track.shp
# Railroad.shp
# Viaduct_centerline.shp
# Stream_wider_than_8_feet.shp
# Cemetery_Outline.shp
# Spot_Elevation.shp
# Other_Retaining_Wall.shp
# Vacant_Area_containing_no_structures.shp
# Emergency_exit.shp
# Parking_Lots___2000_Square_Feet.shp
# Alley.shp
# Transit_entrance.shp
# Abandoned_railroad.shp
# Boardwalk_along_beach.shp
# Soccer_Field.shp
# Wetland.shp
# Rail_Bridge.shp
# Bay_Ocean.shp
# Pond.shp
# Seawall.shp
# Curb.shp
# Sign_Gantry.shp
# Large_Billboard_and_Signs.shp
# Jetty.shp
# Subway_train_station.shp
# Golf_Course.shp
# Lake_Reservoir.shp
# Skating_Rink.shp

# %% [markdown]
# #### Since median is on the road,  use GeoSeries.centroid find the central point  of polygon, and use Pablo's formular to find the nearest segment

# %%
# Since median is on the road,  use GeoSeries.centroid find the central point  of polygon, and use Pablo's formular to find the nearest segment
#test
fea_dataset = gpd.read_file('Shapefiles/Median.shp').to_crs({'init': 'epsg:2263'})
fea_dataset['centroid'] = fea_dataset['geometry'].centroid
fea_dataset.head()
# Out:
#   STREET_NAM     SOURCE_ID  FEATURE_CO  SUB_FEATUR     STATUS  \
# 0       None  2.136000e+10        3600      360010  Unchanged
# 1       None  2.136000e+10        3600      360010  Unchanged
# 2       None  2.136000e+10        3600      360010  Unchanged
# 3       None  2.136000e+10        3600      360020  Unchanged
# 4       None  2.136000e+10        3600      360020  Unchanged
#
#                                             geometry  \
# 0  POLYGON ((990026.1469004154 191974.9441839755,...
# 1  POLYGON ((989996.1381021589 192081.6575532258,...
# 2  POLYGON ((989999.9999710768 191978.6649770588,...
# 3  POLYGON ((990005.4940545857 194189.9856856465,...
# 4  POLYGON ((990007.7463466674 194210.5381379873,...
#
#                                       centroid
# 0  POINT (989777.4015526662 192468.9281117312)
# 1  POINT (989826.1907925971 192405.7067205641)
# 2  POINT (989772.9321044827 192422.5431782209)
# 3  POINT (989992.8631637533 194193.6988815762)
# 4   POINT (989993.1740597539 194210.357510997)

# %%
index = rtree.Rtree()
for idx, geometry in enumerate(segs.geometry):
    index.insert(idx, geometry.bounds)

def closest_segment_id_rtree(point, index, segments):
    match = list(index.nearest((point.x, point.y, point.x, point.y)))
    if len(match):
        return segments.loc[segments.loc[match, 'geometry'].distance(point).idxmin(),'id']
    else:
        return None

# %%
def merge_feature(feature_file = 'Median.shp',df = segs,crs = '2263',sop_var_name = 'median'):
    '''feature is the file name;
    df is sample area;
    crs should be same with df crs;
    Plot the data;
    Return: 2 dataframe
            1st one includes all the detail about this feature
            2nd one includes sop variable column for writting to csv'''
    fea_dataset = gpd.read_file('Shapefiles/'+feature_file).to_crs({'init': 'epsg:'+crs})
    fea_dataset['centroid'] =  fea_dataset['geometry'].centroid
    fea_dataset['segid'] = fea_dataset.centroid.apply(lambda x: closest_segment_id_rtree(x, index, segs))
    #plot sample area
    fig, ax = plt.subplots(figsize=(12,8))
    minx, miny, maxx, maxy = (970000, 150000, 1000000, 190000)
    sample_bounds = box(minx, miny, maxx, maxy)
    segs_b = segs[segs.within(sample_bounds)]
    segs_joined_sample = fea_dataset[fea_dataset.within(sample_bounds)]


    ax.set_title(feature_file +' Sample Area', fontsize=20)
    segs_b.plot(edgecolor='grey', facecolor='lightgrey', ax= ax, lw=0.5, zorder=-1, alpha=0.4)
    segs_joined_sample.plot(edgecolor='lightblue', facecolor='blue', ax= ax, lw=0.5, zorder=-1, alpha=0.4)
    ax.axis('off')
    dt_to_csv = fea_dataset.groupby('segid').count().reset_index(level=0, drop=False)[['SUB_FEATUR','segid']]
    
    dt_to_csv.rename(columns = {'SUB_FEATUR':sop_var_name},inplace =True)
    return fea_dataset,dt_to_csv

# %%
l, median = merge_feature()
l.head()
# Out:
#   STREET_NAM     SOURCE_ID  FEATURE_CO  SUB_FEATUR     STATUS  \
# 0       None  2.136000e+10        3600      360010  Unchanged
# 1       None  2.136000e+10        3600      360010  Unchanged
# 2       None  2.136000e+10        3600      360010  Unchanged
# 3       None  2.136000e+10        3600      360020  Unchanged
# 4       None  2.136000e+10        3600      360020  Unchanged
#
#                                             geometry  \
# 0  POLYGON ((990026.1469004154 191974.9441839755,...
# 1  POLYGON ((989996.1381021589 192081.6575532258,...
# 2  POLYGON ((989999.9999710768 191978.6649770588,...
# 3  POLYGON ((990005.4940545857 194189.9856856465,...
# 4  POLYGON ((990007.7463466674 194210.5381379873,...
#
#                                       centroid  segid
# 0  POINT (989777.4015526662 192468.9281117312)   5335
# 1  POINT (989826.1907925971 192405.7067205641)   5335
# 2  POINT (989772.9321044827 192422.5431782209)   5335
# 3  POINT (989992.8631637533 194193.6988815762)   2328
# 4   POINT (989993.1740597539 194210.357510997)   2328

# %%
# check df to csv
median.head()
# Out:
#    median  segid
# 0       1     66
# 1       1     79
# 2       2     86
# 3       1    107
# 4       1    108

# %%
median.to_csv("joined_median.csv",index=False,sep=',')

# %% [markdown]
# # Apply on other features -Driveway
# #### It's one of the feature in 'Roadbed.shp'
#
# #### 350030: Driveway sub feature number

# %%
def merge_feature_driveway(feature_file = 'Median.shp',df = segs,crs = '2263',sop_var_name = 'median'):
    '''feature is the file name;
    df is sample area;
    crs should be same with df crs;
    Plot the data;
    Return: 2 dataframe
            1st one includes all the detail about this feature
            2nd one includes sop variable column for writting to csv'''
    fea_dataset = gpd.read_file('Shapefiles/'+feature_file).to_crs({'init': 'epsg:'+crs})
    #For Driveway
    fea_dataset = fea_dataset[fea_dataset.SUB_FEATUR == 350030]
    fea_dataset['centroid'] =  fea_dataset['geometry'].centroid
    fea_dataset['segid'] = fea_dataset.centroid.apply(lambda x: closest_segment_id_rtree(x, index, segs))
    #plot sample area
    fig, ax = plt.subplots(figsize=(12,8))
    minx, miny, maxx, maxy = (970000, 150000, 1000000, 190000)
    sample_bounds = box(minx, miny, maxx, maxy)
    segs_b = segs[segs.within(sample_bounds)]
    segs_joined_sample = fea_dataset[fea_dataset.within(sample_bounds)]


    ax.set_title(feature_file +' Sample Area', fontsize=20)
    segs_b.plot(edgecolor='grey', facecolor='lightgrey', ax= ax, lw=0.5, zorder=-1, alpha=0.4)
    segs_joined_sample.plot(edgecolor='lightblue', facecolor='blue', ax= ax, lw=0.5, zorder=-1, alpha=0.4)
    ax.axis('off')
    dt_to_csv = fea_dataset.groupby('segid').count().reset_index(level=0, drop=False)[['SUB_FEATUR','segid']]
    
    dt_to_csv.rename(columns = {'SUB_FEATUR':sop_var_name},inplace =True)
    return fea_dataset,dt_to_csv

# %%
roadbed,roadbed_to_csv = merge_feature_driveway(feature_file = 'Roadbed.shp',df = segs,crs = '2263',sop_var_name = 'driveway')
roadbed.head()
# Out:
#          SOURCE_ID  FEATURE_CO  SUB_FEATUR     STATUS  \
# 1662  7.350002e+09        3500      350030  Unchanged
# 1759  7.350002e+09        3500      350030    Updated
# 1909  7.350002e+09        3500      350030    Updated
# 2424  7.350002e+09        3500      350030    Updated
# 2436  7.350002e+09        3500      350030    Updated
#
#                                                geometry  \
# 1662  POLYGON ((1049301.216998324 200794.5479358137,...
# 1759  POLYGON ((1051111.518823907 203294.2745636404,...
# 1909  POLYGON ((1050255.650128826 203423.2198438197,...
# 2424  POLYGON ((1051358.99306649 203145.0826048106, ...
# 2436  POLYGON ((1051511.668286085 203545.1864634007,...
#
#                                          centroid  segid
# 1662  POINT (1049262.266173546 200884.0402054937)  43779
# 1759   POINT (1050939.691398016 203209.269928531)  16407
# 1909  POINT (1050225.069298363 203437.6385297013)  16408
# 2424  POINT (1051336.598087572 203143.0590398201)  74975
# 2436  POINT (1051544.487139861 203399.7559557433)  74975

# %%
roadbed[roadbed.segid == 456].plot()

# %%
roadbed_to_csv.head()
# Out:
#    driveway  segid
# 0         1    207
# 1         1    456
# 2         1    660
# 3         2    775
# 4         2    861

# %%
roadbed_to_csv.describe()
# Out:
#          driveway         segid
# count  350.000000    350.000000
# mean     1.305714  48049.734286
# std      0.753765  28147.952258
# min      1.000000    207.000000
# 25%      1.000000  23396.500000
# 50%      1.000000  49938.000000
# 75%      1.000000  73569.500000
# max      6.000000  91661.000000

# %%
roadbed_to_csv.driveway.value_counts()
# Out:
# 1    281
# 2     45
# 3     17
# 6      3
# 4      3
# 5      1
# Name: driveway, dtype: int64

# %%
roadbed_to_csv.driveway = roadbed_to_csv.driveway.apply(lambda x: 2 if x>=2 else x)
roadbed_to_csv.driveway.value_counts()
# Out:
# 1    281
# 2     69
# Name: driveway, dtype: int64

# %% [markdown]
# #### Cannot tell how many driveways, only classify to have driveway with "driveway"> 0 and no driveway with feature=0

# %%
roadbed_to_csv.to_csv("joined_driveway.csv",index=False,sep=',')

# %% [markdown]
# # Apply on other features -Parking lot_2000sqft (not travel-way)

# %%
parkinglot, parkinglot_2000 = merge_feature(feature_file = 'Parking_Lots___2000_Square_Feet.shp',\
                                            df = segs,crs = '2263',sop_var_name = 'surfpkng')
parkinglot.head()
# Out:
#       SOURCE_ID  FEATURE_CO  SUB_FEATUR     STATUS  \
# 0  2.150000e+10        5000      500000  Unchanged
# 1  2.150000e+10        5000      500000    Updated
# 2  2.150000e+10        5000      500000  Unchanged
# 3  2.150000e+10        5000      500000  Unchanged
# 4  2.150000e+10        5000      500000  Unchanged
#
#                                             geometry  \
# 0  POLYGON ((990044.4431236684 190843.5957248956,...
# 1  POLYGON ((989953.2139754146 191814.4684550613,...
# 2  POLYGON ((988897.051389575 195330.5549268126, ...
# 3  POLYGON ((989270.8839752525 195436.5458565652,...
# 4  POLYGON ((988145.6890471578 195152.533957392, ...
#
#                                       centroid  segid
# 0  POINT (990029.3636842157 190739.7197202197)   5339
# 1  POINT (989730.7282890398 191626.4517265979)   5338
# 2  POINT (988847.3157554124 195306.7784605023)   3452
# 3  POINT (989229.8061570526 195424.2433645794)   3455
# 4  POINT (988214.4357064107 195019.9356224579)  23148

# %%
parkinglot_2000.head()
# Out:
#    surfpkng  segid
# 0         1      5
# 1         2     16
# 2         3     17
# 3         2     24
# 4         1     26

# %%
parkinglot_2000.to_csv("joined_parkinglot_2000.csv",index=False,sep=',')

# %%
os.listdir('Shapefiles/')
# Out:
# ['Sidewalk.dbf',
#  'Railway_fence.sbx',
#  'Ventilation_grate.shx',
#  'Median.shx',
#  'Airport_Runways.prj',
#  'Viaduct_centerline.sbn',
#  'Elevated_railroad.shp',
#  'Tunnel.sbx',
#  'Embankment_railroad.dbf',
#  'Parking_Lots___2000_Square_Feet.shp.xml',
#  'Railroad_Viaduct.prj',
#  'Park_Boundary.prj',
#  'Stream_wider_than_8_feet.sbn',
#  'Toll_Area.prj',
#  'Lake_Reservoir.shp.xml',
#  'Elevated_railroad.cpg',
#  'Water_Elevation.shp',
#  'Railroad.sbn',
#  'Roadbed.dbf',
#  'Railroad_Retaining_Wall.cpg',
#  'Railroad_Retaining_Wall.shp',
#  'Running_Track.prj',
#  'Pier.prj',
#  'Water_Elevation.cpg',
#  'Alley.shp.xml',
#  'Tunnel.shx',
#  'Bridge.shp',
#  'Interior_Sidewalk_Centerline.cpg',
#  'Median.sbx',
#  'Ventilation_grate.sbx',
#  'Railway_fence.shx',
#  'Interior_Sidewalk_Centerline.shp',
#  'Plaza.dbf',
#  'Bridge.cpg',
#  'Toll_Area.shp.xml',
#  'Median.shp',
#  'Ventilation_grate.shp',
#  'Interior_Sidewalk_Centerline.sbx',
#  'River.dbf',
#  'Railroad.prj',
#  'Bridge.sbx',
#  'Plaza.shp.xml',
#  'Median.cpg',
#  'Ventilation_grate.cpg',
#  'Running_Track.sbn',
#  'Pier.sbn',
#  'Railroad_Retaining_Wall.sbx',
#  'Elevated_railroad.shx',
#  'Water_Elevation.sbx',
#  'Pedestrian_Bridge.dbf',
#  'Tunnel.cpg',
#  'Water_Elevation.shx',
#  'Airport_Runways.sbn',
#  'Tunnel.shp',
#  'Elevated_railroad.sbx',
#  'Viaduct_centerline.prj',
#  'Railroad_Retaining_Wall.shx',
#  'Railroad_Viaduct.sbn',
#  'Railway_fence.cpg',
#  'Stream_wider_than_8_feet.prj',
#  'Park_Boundary.sbn',
#  'Shoreline.dbf',
#  'Bridge.shx',
#  'Interior_Sidewalk_Centerline.shx',
#  'Railway_fence.shp',
#  'Elevated_subway_train_station.dbf',
#  'Toll_Area.sbn',
#  'Greenstreets.cpg',
#  'Railroad.shp.xml',
#  'Open_cut_depression_railroad.dbf',
#  'Cemetery_Outline.prj',
#  'Greenstreets.shp',
#  'Transit_entrance.sbn',
#  'Swimming_Pool.dbf',
#  'Alley.sbn',
#  'Building_Elevation.shp',
#  'Abandoned_railroad.sbn',
#  'Bay_Ocean.shp.xml',
#  'Football_Field.shx',
#  'Spot_Elevation.prj',
#  'Other_Retaining_Wall.prj',
#  'Baseball_Softball_Field.sbx',
#  'Building_Elevation.cpg',
#  'Baseball_Softball_Field.shx',
#  'Beach_Shoreline.cpg',
#  'Football_Field.sbx',
#  'Beach_Shoreline.shp',
#  'Emergency_exit.prj',
#  'Court.dbf',
#  'Vacant_Area_containing_no_structures.prj',
#  'Elevated_subway_train_station.shp.xml',
#  'Pool.shp',
#  'Parking_Lots___2000_Square_Feet.sbn',
#  'Pool.cpg',
#  'Greenstreets.shp.xml',
#  'Building_Elevation.shp.xml',
#  'Pool.sbx',
#  'Greenstreets.shx',
#  'Road_Edge.dbf',
#  'Beach_Shoreline.sbx',
#  'Football_Field.shp',
#  'Parking_Lots___2000_Square_Feet.prj',
#  'Roadbed.shp.xml',
#  'Emergency_exit.sbn',
#  'Building_Elevation.shx',
#  'Vacant_Area_containing_no_structures.sbn',
#  'Wetland.shp.xml',
#  'Football_Field.cpg',
#  'Baseball_Softball_Field.shp',
#  'Baseball_Softball_Field.cpg',
#  'Building_Elevation.sbx',
#  'Beach_Shoreline.shx',
#  'Cemetery_Outline.sbn',
#  'Abandoned_railroad.prj',
#  'Overpass.dbf',
#  'Recreational_area__Not_NYC_designated_parks_.dbf',
#  'Spot_Elevation.sbn',
#  'Transit_entrance.prj',
#  'Greenstreets.sbx',
#  'Pool.shx',
#  'Alley.prj',
#  'Court.shp.xml',
#  'Other_Retaining_Wall.sbn',
#  'Rail_Bridge.sbn',
#  'Swimming_Pool.sbx',
#  'Wetland.sbn',
#  'Bay_Ocean.sbn',
#  'Baseball_Softball_Field.dbf',
#  'Pond.sbn',
#  'Recreational_area__Not_NYC_designated_parks_.cpg',
#  'Sign_Gantry.shp.xml',
#  'Open_cut_depression_railroad.sbx',
#  'Overpass.cpg',
#  'Seawall.sbn',
#  'Recreational_area__Not_NYC_designated_parks_.shp',
#  'Boardwalk_along_beach.prj',
#  'Overpass.shp',
#  'Court.shx',
#  'Vacant_Area_containing_no_structures.shp.xml',
#  'Curb.sbn',
#  'Court.sbx',
#  'Open_cut_depression_railroad.shx',
#  'Soccer_Field.prj',
#  'Road_Edge.cpg',
#  'Football_Field.dbf',
#  'Road_Edge.shp',
#  'Swimming_Pool.shx',
#  'Beach_Shoreline.dbf',
#  'Road_Edge.sbx',
#  'Soccer_Field.sbn',
#  'Boardwalk_along_beach.shp.xml',
#  'Court.cpg',
#  'Pool.dbf',
#  'Court.shp',
#  'Overpass.shx',
#  'Recreational_area__Not_NYC_designated_parks_.shx',
#  'Recreational_area__Not_NYC_designated_parks_.sbx',
#  'Bay_Ocean.prj',
#  'Open_cut_depression_railroad.cpg',
#  'Overpass.sbx',
#  'Rail_Bridge.prj',
#  'Curb.shp.xml',
#  'Greenstreets.dbf',
#  'Wetland.prj',
#  'Open_cut_depression_railroad.shp',
#  'Pond.prj',
#  'Swimming_Pool.cpg',
#  'Building_Elevation.dbf',
#  'Median.shp.xml',
#  'Running_Track.shp.xml',
#  'Swimming_Pool.shp',
#  'Curb.prj',
#  'Seawall.prj',
#  'Road_Edge.shx',
#  'Boardwalk_along_beach.sbn',
#  'Large_Billboard_and_Signs.shp.xml',
#  'Cemetery_Outline.shp.xml',
#  'Embankment_railroad.sbx',
#  'Tunnel.dbf',
#  'Roadbed.shx',
#  'Large_Billboard_and_Signs.prj',
#  'Plaza.shx',
#  'Sidewalk.sbx',
#  'Elevated_subway_train_station.shp',
#  'Shoreline.cpg',
#  'Recreational_area__Not_NYC_designated_parks_.shp.xml',
#  'Sign_Gantry.prj',
#  'Lake_Reservoir.sbn',
#  'Railway_fence.dbf',
#  'Shoreline.shp',
#  'Elevated_subway_train_station.cpg',
#  'Interior_Sidewalk_Centerline.shp.xml',
#  'Baseball_Softball_Field.shp.xml',
#  'Skating_Rink.sbn',
#  'Jetty.prj',
#  'River.cpg',
#  'Subway_train_station.sbn',
#  'Golf_Course.sbn',
#  'Elevated_railroad.shp.xml',
#  'Ventilation_grate.dbf',
#  'Median.dbf',
#  'River.shp',
#  'Sidewalk.shx',
#  'Plaza.sbx',
#  'Pedestrian_Bridge.shp',
#  'Roadbed.sbx',
#  'Embankment_railroad.shx',
#  'Pedestrian_Bridge.cpg',
#  'Railroad_Retaining_Wall.dbf',
#  'Golf_Course.prj',
#  'Roadbed.cpg',
#  'Open_cut_depression_railroad.shp.xml',
#  'Subway_train_station.prj',
#  'Swimming_Pool.shp.xml',
#  'Pedestrian_Bridge.sbx',
#  'Water_Elevation.dbf',
#  'Roadbed.shp',
#  'Elevated_subway_train_station.shx',
#  'River.sbx',
#  'Interior_Sidewalk_Centerline.dbf',
#  'Bridge.shp.xml',
#  'Plaza.shp',
#  'Plaza.cpg',
#  'Bridge.dbf',
#  'Shoreline.shx',
#  'Shoreline.sbx',
#  'Sidewalk.cpg',
#  'Overpass.shp.xml',
#  'River.shx',
#  'Sidewalk.shp',
#  'Elevated_subway_train_station.sbx',
#  'Lake_Reservoir.prj',
#  'Sign_Gantry.sbn',
#  'Pedestrian_Bridge.shx',
#  'Large_Billboard_and_Signs.sbn',
#  'Embankment_railroad.cpg',
#  'Elevated_railroad.dbf',
#  'Skating_Rink.prj',
#  'Jetty.sbn',
#  'Embankment_railroad.shp',
#  'Airport_Runways.cpg',
#  'Railroad.shx',
#  'Tunnel.shp.xml',
#  'Tunnel.sbn',
#  'Airport_Runways.shp',
#  'Stream_wider_than_8_feet.sbx',
#  'Toll_Area.cpg',
#  'Park_Boundary.shp',
#  'Railroad_Viaduct.shp',
#  'Viaduct_centerline.sbx',
#  'Elevated_railroad.prj',
#  'Skating_Rink.dbf',
#  'Toll_Area.shp',
#  'Subway_train_station.shp.xml',
#  'Railroad_Viaduct.cpg',
#  'Lake_Reservoir.dbf',
#  'Railway_fence.sbn',
#  'Park_Boundary.cpg',
#  'Running_Track.cpg',
#  'Ventilation_grate.sbn',
#  'Pier.cpg',
#  'Median.sbn',
#  'Water_Elevation.prj',
#  'Viaduct_centerline.shx',
#  'Subway_train_station.dbf',
#  'Pier.shp',
#  'Running_Track.shp',
#  'Golf_Course.dbf',
#  'Railroad_Retaining_Wall.prj',
#  'Stream_wider_than_8_feet.shx',
#  'Bridge.prj',
#  'Railroad.sbx',
#  'Interior_Sidewalk_Centerline.prj',
#  'Railroad.shp',
#  'Water_Elevation.sbn',
#  'Ventilation_grate.prj',
#  'Median.prj',
#  'Railroad_Retaining_Wall.sbn',
#  'Railroad.cpg',
#  'Airport_Runways.shx',
#  'Soccer_Field.shp.xml',
#  'Bridge.sbn',
#  'Running_Track.sbx',
#  'Park_Boundary.shx',
#  'Pier.sbx',
#  'Railroad_Viaduct.shx',
#  'Toll_Area.shx',
#  'Interior_Sidewalk_Centerline.sbn',
#  'Pier.shp.xml',
#  'Viaduct_centerline.cpg',
#  'Toll_Area.sbx',
#  'Railroad_Viaduct.sbx',
#  'Pier.shx',
#  'Park_Boundary.sbx',
#  'Running_Track.shx',
#  'Viaduct_centerline.shp',
#  'Tunnel.prj',
#  'Jetty.dbf',
#  'Airport_Runways.sbx',
#  'Elevated_railroad.sbn',
#  'Stream_wider_than_8_feet.shp',
#  'Sign_Gantry.dbf',
#  'Railway_fence.prj',
#  'Stream_wider_than_8_feet.cpg',
#  'Large_Billboard_and_Signs.dbf',
#  'Cemetery_Outline.cpg',
#  'Baseball_Softball_Field.sbn',
#  'Alley.sbx',
#  'Rail_Bridge.dbf',
#  'Greenstreets.prj',
#  'Transit_entrance.sbx',
#  'Wetland.dbf',
#  'Bay_Ocean.dbf',
#  'Cemetery_Outline.shp',
#  'Abandoned_railroad.sbx',
#  'Seawall.dbf',
#  'Spot_Elevation.shp',
#  'Parking_Lots___2000_Square_Feet.shx',
#  'Other_Retaining_Wall.cpg',
#  'Building_Elevation.prj',
#  'Curb.dbf',
#  'Pond.dbf',
#  'Abandoned_railroad.shp.xml',
#  'Spot_Elevation.cpg',
#  'Road_Edge.shp.xml',
#  'Other_Retaining_Wall.shp',
#  'Airport_Runways.shp.xml',
#  'Beach_Shoreline.prj',
#  'Parking_Lots___2000_Square_Feet.sbx',
#  'Football_Field.sbn',
#  'Railroad_Retaining_Wall.shp.xml',
#  'Abandoned_railroad.shx',
#  'Pool.prj',
#  'Transit_entrance.shx',
#  'Vacant_Area_containing_no_structures.shp',
#  'Emergency_exit.shp',
#  'Alley.shx',
#  'Emergency_exit.cpg',
#  'Ventilation_grate.shp.xml',
#  'Vacant_Area_containing_no_structures.cpg',
#  'Shoreline.shp.xml',
#  'Soccer_Field.dbf',
#  'Cemetery_Outline.shx',
#  'Beach_Shoreline.sbn',
#  'Emergency_exit.sbx',
#  'Vacant_Area_containing_no_structures.sbx',
#  'Pool.sbn',
#  'Parking_Lots___2000_Square_Feet.shp',
#  'Football_Field.prj',
#  'Spot_Elevation.shx',
#  'Other_Retaining_Wall.shx',
#  'Parking_Lots___2000_Square_Feet.cpg',
#  'Railway_fence.shp.xml',
#  'Baseball_Softball_Field.prj',
#  'Other_Retaining_Wall.sbx',
#  'Spot_Elevation.sbx',
#  'Greenstreets.sbn',
#  'Vacant_Area_containing_no_structures.shx',
#  'Building_Elevation.sbn',
#  'Emergency_exit.shx',
#  'Alley.shp',
#  'Transit_entrance.shp',
#  'Boardwalk_along_beach.dbf',
#  'Abandoned_railroad.shp',
#  'Cemetery_Outline.sbx',
#  'Abandoned_railroad.cpg',
#  'Alley.cpg',
#  'Jetty.shp.xml',
#  'Transit_entrance.cpg',
#  'Seawall.sbx',
#  'Emergency_exit.shp.xml',
#  'Curb.sbx',
#  'Pond.sbx',
#  'Open_cut_depression_railroad.sbn',
#  'Boardwalk_along_beach.cpg',
#  'Viaduct_centerline.shp.xml',
#  'Swimming_Pool.sbn',
#  'Transit_entrance.dbf',
#  'Wetland.sbx',
#  'Rail_Bridge.sbx',
#  'Alley.dbf',
#  'Football_Field.shp.xml',
#  'Abandoned_railroad.dbf',
#  'Boardwalk_along_beach.shp',
#  'Overpass.prj',
#  'Recreational_area__Not_NYC_designated_parks_.prj',
#  'Bay_Ocean.sbx',
#  'Bay_Ocean.shx',
#  'Transit_entrance.shp.xml',
#  'Soccer_Field.cpg',
#  'Rail_Bridge.shx',
#  'Wetland.shx',
#  'Soccer_Field.shp',
#  'Skating_Rink.shp.xml',
#  'Other_Retaining_Wall.shp.xml',
#  'Pond.shx',
#  'Rail_Bridge.shp.xml',
#  'Stream_wider_than_8_feet.shp.xml',
#  'Court.sbn',
#  'Curb.shx',
#  'Seawall.shx',
#  'Road_Edge.prj',
#  'Parking_Lots___2000_Square_Feet.dbf',
#  'Pool.shp.xml',
#  'Golf_Course.shp.xml',
#  'Beach_Shoreline.shp.xml',
#  'Soccer_Field.sbx',
#  'Road_Edge.sbn',
#  'Boardwalk_along_beach.shx',
#  'Court.prj',
#  'Vacant_Area_containing_no_structures.dbf',
#  'Emergency_exit.dbf',
#  'Wetland.shp',
#  'Pedestrian_Bridge.shp.xml',
#  'Rail_Bridge.shp',
#  'Boardwalk_along_beach.sbx',
#  'Cemetery_Outline.dbf',
#  'Bay_Ocean.shp',
#  'Open_cut_depression_railroad.prj',
#  'Bay_Ocean.cpg',
#  'Wetland.cpg',
#  'Rail_Bridge.cpg',
#  'Soccer_Field.shx',
#  'Curb.cpg',
#  'Pond.shp',
#  'Other_Retaining_Wall.dbf',
#  'Water_Elevation.shp.xml',
#  'Seawall.cpg',
#  'Overpass.sbn',
#  'Recreational_area__Not_NYC_designated_parks_.sbn',
#  'Seawall.shp',
#  'Spot_Elevation.dbf',
#  'Curb.shp',
#  'Swimming_Pool.prj',
#  'Pond.cpg',
#  'Golf_Course.shx',
#  'Skating_Rink.sbx',
#  'Viaduct_centerline.dbf',
#  'Subway_train_station.shx',
#  'Sidewalk.sbn',
#  'Lake_Reservoir.sbx',
#  'Sign_Gantry.shp',
#  'Elevated_subway_train_station.prj',
#  'Jetty.cpg',
#  'Large_Billboard_and_Signs.shp',
#  'Embankment_railroad.sbn',
#  'Jetty.shp',
#  'Large_Billboard_and_Signs.cpg',
#  'Stream_wider_than_8_feet.dbf',
#  'Sign_Gantry.cpg',
#  'Shoreline.prj',
#  'Spot_Elevation.shp.xml',
#  'Railroad_Viaduct.shp.xml',
#  'Railroad.dbf',
#  'River.prj',
#  'Roadbed.sbn',
#  'Lake_Reservoir.shx',
#  'Plaza.sbn',
#  'Pedestrian_Bridge.prj',
#  'Subway_train_station.sbx',
#  'Skating_Rink.shx',
#  'Golf_Course.sbx',
#  'Subway_train_station.shp',
#  'River.shp.xml',
#  'Golf_Course.shp',
#  'Sidewalk.shp.xml',
#  'Pier.dbf',
#  'Running_Track.dbf',
#  'Roadbed.prj',
#  'Golf_Course.cpg',
#  'Subway_train_station.cpg',
#  'River.sbn',
#  'Plaza.prj',
#  'Large_Billboard_and_Signs.shx',
#  'Pedestrian_Bridge.sbn',
#  'Sign_Gantry.shx',
#  'Park_Boundary.shp.xml',
#  'Pond.shp.xml',
#  'Seawall.shp.xml',
#  'Jetty.shx',
#  'Airport_Runways.dbf',
#  'Jetty.sbx',
#  'Embankment_railroad.shp.xml',
#  'Sign_Gantry.sbx',
#  'Sidewalk.prj',
#  'Large_Billboard_and_Signs.sbx',
#  'Skating_Rink.cpg',
#  'Lake_Reservoir.shp',
#  'Toll_Area.dbf',
#  'Elevated_subway_train_station.sbn',
#  'Park_Boundary.dbf',
#  'Railroad_Viaduct.dbf',
#  'Lake_Reservoir.cpg',
#  'Shoreline.sbn',
#  'Embankment_railroad.prj',
#  'Skating_Rink.shp']

# %%
def merge_feature_buffer(feature_file = 'Median.shp',df = segs, crs = '2263',sop_var_name = 'median'):
    '''feature is the file name;
    df is sample area;
    crs should be same with df crs;
    Plot the data;
    Return: 2 dataframe
            1st one includes all the detail about this feature
            2nd one includes sop variable column for writting to csv'''
    fea_dataset = gpd.read_file('Shapefiles/'+feature_file).to_crs({'init': 'epsg:'+crs})
    fea_dataset_copy = fea_dataset.copy()
    fea_dataset['geometry'] = fea_dataset.geometry.buffer(200, cap_style=2)
    
    #plot sample area
    fig, ax = plt.subplots(figsize=(12,8))
    minx, miny, maxx, maxy = (970000, 150000, 1000000, 190000)
    sample_bounds = box(minx, miny, maxx, maxy)
    segs_b = segs[segs.within(sample_bounds)]
    segs_joined_sample = fea_dataset[fea_dataset_copy.within(sample_bounds)]


    ax.set_title(feature_file +' Sample Area', fontsize=20)
    segs_b.plot(edgecolor='grey', facecolor='lightgrey', ax= ax, lw=0.5, zorder=-1, alpha=0.4)
    segs_joined_sample.plot(edgecolor='lightblue', facecolor='blue', ax= ax, lw=0.5, zorder=-1, alpha=0.4)
    ax.axis('off')
    
    
    fea_dataset = gpd.sjoin(fea_dataset, segs, how  = 'left')
    fea_dataset = fea_dataset[fea_dataset['id'] >= 0]
    dt_to_csv = fea_dataset.groupby('id').count().reset_index(level=0, drop=False)[['SUB_FEATUR','id']]
    dt_to_csv.rename(columns = {'SUB_FEATUR':sop_var_name,'id':'segid'},inplace =True)
    dt_to_csv[sop_var_name] = dt_to_csv[sop_var_name].apply(lambda x: 1 if x>0 else 0)
    return fea_dataset,dt_to_csv

# %% [markdown]
# # Apply on other features - Park

# %%
park, park_to_csv = merge_feature_buffer(feature_file = 'Park_Boundary.shp',\
                                            df = segs,crs = '2263',sop_var_name = 'parkplay')
park.head()
# Out:
#                PARK_NAME     SOURCE_ID  FEATURE_CO  SUB_FEATUR  \
# 0  Pierrepont Playground  2.149800e+10        4980      498000
# 0  Pierrepont Playground  2.149800e+10        4980      498000
# 0  Pierrepont Playground  2.149800e+10        4980      498000
# 0  Pierrepont Playground  2.149800e+10        4980      498000
# 0  Pierrepont Playground  2.149800e+10        4980      498000
#
#              LANDUSE PARKNUM     STATUS SYSTEM  \
# 0  Neighborhood Park    B222  Unchanged   None
# 0  Neighborhood Park    B222  Unchanged   None
# 0  Neighborhood Park    B222  Unchanged   None
# 0  Neighborhood Park    B222  Unchanged   None
# 0  Neighborhood Park    B222  Unchanged   None
#
#                                             geometry  index_right  ...  \
# 0  POLYGON ((984686.2699846938 193100.8228352284,...      81910.0  ...
# 0  POLYGON ((984686.2699846938 193100.8228352284,...      15258.0  ...
# 0  POLYGON ((984686.2699846938 193100.8228352284,...      36828.0  ...
# 0  POLYGON ((984686.2699846938 193100.8228352284,...      14307.0  ...
# 0  POLYGON ((984686.2699846938 193100.8228352284,...       1309.0  ...
#
#    RBlockFace FIRST_Traf MAX_Number MAX_Numb_1 MAX_Numb_2 MAX_POSTED  \
# 0        None          P          6          2          6         50
# 0  0212260284          A          1          1          2         20
# 0  0212260008          A          3       None          3         45
# 0  0212260285          W          1          2          3         20
# 0  0212260094          W          3       None          3         45
#
#   FIRST_Bike                     FIRST_Stre MAX_Street MIN_Street
# 0       None  E 174 ST BR PED AND BIKE PATH      142.0        0.0
# 0       None               COLUMBIA HEIGHTS       22.0       22.0
# 0       None     BROOKLYN QUEENS EXPRESSWAY       34.0       18.0
# 0       None               MONTAGUE TERRACE       26.0       26.0
# 0       None     BROOKLYN QUEENS EXPRESSWAY       38.0       36.0
#
# [5 rows x 39 columns]

# %%
park_to_csv.describe()
# Out:
#        parkplay         segid
# count   27127.0  27127.000000
# mean        1.0  46313.783279
# std         0.0  26459.426022
# min         1.0     28.000000
# 25%         1.0  22662.500000
# 50%         1.0  47043.000000
# 75%         1.0  69592.500000
# max         1.0  91649.000000

# %%
park_to_csv.to_csv("joined_parkplay.csv",index=False,sep=',')

# %% [markdown]
# # Apply on other features - Playing sport field

# %%
football, football_to_csv = merge_feature_buffer(feature_file = 'Football_Field.shp',\
                                            df = segs,crs = '2263',sop_var_name = 'playsprt_football')


football.head()
# Out:
#   PARK_NAME     SOURCE_ID  FEATURE_CO  SUB_FEATUR LANDUSE PARKNUM STATUS  \
# 0   M.S. 53  1.492000e+09        4920      492000    None    QS11    New
# 0   M.S. 53  1.492000e+09        4920      492000    None    QS11    New
# 0   M.S. 53  1.492000e+09        4920      492000    None    QS11    New
# 0   M.S. 53  1.492000e+09        4920      492000    None    QS11    New
# 0   M.S. 53  1.492000e+09        4920      492000    None    QS11    New
#
#   SYSTEM                                           geometry  index_right  ...  \
# 0   None  POLYGON ((1053410.450951164 159493.9149079245,...      55451.0  ...
# 0   None  POLYGON ((1053410.450951164 159493.9149079245,...      34978.0  ...
# 0   None  POLYGON ((1053410.450951164 159493.9149079245,...      58453.0  ...
# 0   None  POLYGON ((1053410.450951164 159493.9149079245,...      58454.0  ...
# 0   None  POLYGON ((1053410.450951164 159493.9149079245,...      58455.0  ...
#
#    RBlockFace FIRST_Traf MAX_Number MAX_Numb_1 MAX_Numb_2 MAX_POSTED  \
# 0  0012263395          A          1          2          3         25
# 0  0012263472          W          1          2          3         25
# 0  0012262701          A          1          2          3         25
# 0  0012263413          A          1          2          3         25
# 0  0012262700          A          1          2          3         25
#
#   FIRST_Bike       FIRST_Stre MAX_Street MIN_Street
# 0       None   NAMEOKE STREET       26.0       26.0
# 0       None  BEACH 18 STREET       30.0       28.0
# 0       None  DINSMORE AVENUE       30.0       30.0
# 0       None    BAYPORT PLACE       28.0       25.0
# 0       None   NAMEOKE STREET       30.0       30.0
#
# [5 rows x 39 columns]

# %%
football_to_csv.describe()
# Out:
#        playsprt_football         segid
# count              136.0    136.000000
# mean                 1.0  42702.088235
# std                  0.0  26194.227010
# min                  1.0    156.000000
# 25%                  1.0  21214.750000
# 50%                  1.0  41729.500000
# 75%                  1.0  65670.500000
# max                  1.0  91462.000000

# %%
football_to_csv.to_csv("joined_playsprt_football.csv",index=False,sep=',')

# %%
baseballfield, baseballfield_to_csv = merge_feature_buffer(feature_file = 'Baseball_Softball_Field.shp',\
                                            df = segs,crs = '2263',sop_var_name = 'playsprt_baseball')


baseballfield.head()
# Out:
#               PARK_NAME     SOURCE_ID  FEATURE_CO  SUB_FEATUR LANDUSE PARKNUM  \
# 0  Commodore Barry Park  2.149000e+10        4900      490020    None    B021
# 0  Commodore Barry Park  2.149000e+10        4900      490020    None    B021
# 0  Commodore Barry Park  2.149000e+10        4900      490020    None    B021
# 0  Commodore Barry Park  2.149000e+10        4900      490020    None    B021
# 0  Commodore Barry Park  2.149000e+10        4900      490020    None    B021
#
#       STATUS             SYSTEM  \
# 0  Unchanged  B021-BASEBALL-151
# 0  Unchanged  B021-BASEBALL-151
# 0  Unchanged  B021-BASEBALL-151
# 0  Unchanged  B021-BASEBALL-151
# 0  Unchanged  B021-BASEBALL-151
#
#                                             geometry  index_right  ...  \
# 0  POLYGON ((989790.8778484941 193055.2582125658,...      73872.0  ...
# 0  POLYGON ((989790.8778484941 193055.2582125658,...      73847.0  ...
# 0  POLYGON ((989790.8778484941 193055.2582125658,...      21213.0  ...
# 0  POLYGON ((989790.8778484941 193055.2582125658,...      21214.0  ...
# 0  POLYGON ((989790.8778484941 193055.2582125658,...      21204.0  ...
#
#    RBlockFace FIRST_Traf MAX_Number MAX_Numb_1 MAX_Numb_2 MAX_POSTED  \
# 0  0212260765          T          2          1          3         25
# 0  0212260008          A          3       None          3         45
# 0  0212260765          T          2          1          3         25
# 0  0212262224          W          1          2          3         25
# 0  0212261016          T          3          2          5         25
#
#   FIRST_Bike                  FIRST_Stre MAX_Street MIN_Street
# 0          2                 NAVY STREET       54.0       40.0
# 0       None  BROOKLYN QUEENS EXPRESSWAY       36.0       30.0
# 0          2                 NAVY STREET       54.0       40.0
# 0       None              CONCORD STREET       30.0       28.0
# 0          2                 NAVY STREET       68.0       54.0
#
# [5 rows x 39 columns]

# %%
baseballfield_to_csv.describe()
# Out:
#        playsprt_baseball         segid
# count             1730.0   1730.000000
# mean                 1.0  44954.261850
# std                  0.0  26055.827547
# min                  1.0    156.000000
# 25%                  1.0  22766.500000
# 50%                  1.0  44798.500000
# 75%                  1.0  67734.750000
# max                  1.0  91331.000000

# %%
baseballfield_to_csv.to_csv("joined_playsprt_baseball.csv",index=False,sep=',')

# %%
#swim
swim, swim_to_csv = merge_feature_buffer(feature_file = 'Swimming_Pool.shp',\
                                            df = segs,crs = '2263',sop_var_name = 'playsprt_swim')

# %%
swim_to_csv.describe()
# Out:
#        playsprt_swim         segid
# count        16333.0  16333.000000
# mean             1.0  51030.631054
# std              0.0  28137.348508
# min              1.0     24.000000
# 25%              1.0  25683.000000
# 50%              1.0  56546.000000
# 75%              1.0  76636.000000
# max              1.0  91658.000000

# %%
swim_to_csv.to_csv("joined_playsprt_swimpool.csv",index=False,sep=',')

# %% [markdown]
# # Apply on other features - Plaza

# %%
plaza,plaza_to_csv = merge_feature_buffer(feature_file = 'Plaza.shp',\
                                            df = segs,crs = '2263',sop_var_name = 'plazasq')



plaza.head()
# Out:
#       SOURCE_ID  FEATURE_CO  SUB_FEATUR     STATUS  \
# 0  2.160000e+10        6000      600000  Unchanged
# 0  2.160000e+10        6000      600000  Unchanged
# 0  2.160000e+10        6000      600000  Unchanged
# 0  2.160000e+10        6000      600000  Unchanged
# 0  2.160000e+10        6000      600000  Unchanged
#
#                                             geometry  index_right access  \
# 0  POLYGON ((987723.0912813171 193931.4574087231,...      23147.0   None
# 0  POLYGON ((987723.0912813171 193931.4574087231,...      14737.0   None
# 0  POLYGON ((987723.0912813171 193931.4574087231,...      15434.0   None
# 0  POLYGON ((987723.0912813171 193931.4574087231,...      82622.0   None
# 0  POLYGON ((987723.0912813171 193931.4574087231,...      37246.0   None
#
#   bridge        from   highway  ...  RBlockFace FIRST_Traf MAX_Number  \
# 0    yes    42482557  motorway  ...  0212261620          T          3
# 0    yes   588455736  motorway  ...  0212260021          W          2
# 0    yes   451028274  motorway  ...  0212261867          A          2
# 0   None   494509167   primary  ...  0212261934          W          2
# 0   None  3413665526   primary  ...  0212262231          W          2
#
#   MAX_Numb_1 MAX_Numb_2 MAX_POSTED FIRST_Bike                 FIRST_Stre  \
# 0       None          3         35       None  MANHATTAN BRIDGE APPROACH
# 0       None          2         35       None           MANHATTAN BRIDGE
# 0       None          2         35       None           MANHATTAN BRIDGE
# 0       None          2         25       None               SANDS STREET
# 0       None          2         25       None               SANDS STREET
#
#   MAX_Street MIN_Street
# 0       42.0       32.0
# 0       36.0       22.0
# 0       28.0       22.0
# 0       34.0       32.0
# 0       32.0       32.0
#
# [5 rows x 35 columns]

# %%
plaza_to_csv.describe()
# Out:
#        plazasq         segid
# count   5801.0   5801.000000
# mean       1.0  50669.310464
# std        0.0  27309.288418
# min        1.0    184.000000
# 25%        1.0  25202.000000
# 50%        1.0  54252.000000
# 75%        1.0  75669.000000
# max        1.0  91660.000000

# %%
plaza_to_csv.to_csv("joined_plazasq.csv",index=False,sep=',')

# %% [markdown]
# # Apply on other features - Greenstreet(Public Garden)

# %%
g,g_to_csv = merge_feature_buffer(feature_file = 'Greenstreets.shp',\
                                            df = segs,crs = '2263',sop_var_name = 'pubgardn')



g.head()
# Out:
#      PARK_NAME     SOURCE_ID  FEATURE_CO  SUB_FEATUR LANDUSE PARKNUM  \
# 0  GREENSTREET  2.149850e+10        4985      498500    None    BZ08
# 0  GREENSTREET  2.149850e+10        4985      498500    None    BZ08
# 0  GREENSTREET  2.149850e+10        4985      498500    None    BZ08
# 0  GREENSTREET  2.149850e+10        4985      498500    None    BZ08
# 0  GREENSTREET  2.149850e+10        4985      498500    None    BZ08
#
#       STATUS SYSTEM                                           geometry  \
# 0  Unchanged   BZ08  POLYGON ((988437.717334494 192733.0931863189, ...
# 0  Unchanged   BZ08  POLYGON ((988437.717334494 192733.0931863189, ...
# 0  Unchanged   BZ08  POLYGON ((988437.717334494 192733.0931863189, ...
# 0  Unchanged   BZ08  POLYGON ((988437.717334494 192733.0931863189, ...
# 0  Unchanged   BZ08  POLYGON ((988437.717334494 192733.0931863189, ...
#
#    index_right  ...  RBlockFace FIRST_Traf MAX_Number MAX_Numb_1 MAX_Numb_2  \
# 0      35022.0  ...  0212260077          A          3          1          4
# 0      35035.0  ...  0212260543          W          1          1          2
# 0      35036.0  ...  0212262092          W          3          1          4
# 0      22289.0  ...  0212260865          W          2          1          3
# 0      58897.0  ...  0212260594          A          4          1          5
#
#   MAX_POSTED FIRST_Bike                 FIRST_Stre MAX_Street MIN_Street
# 0         25       None  FLATBUSH AVENUE EXTENSION       44.0       42.0
# 0         25       None            CATHEDRAL PLACE       18.0       18.0
# 0         25       None  FLATBUSH AVENUE EXTENSION       42.0       42.0
# 0         25       None  FLATBUSH AVENUE EXTENSION       32.0       32.0
# 0         25       None  FLATBUSH AVENUE EXTENSION       50.0       50.0
#
# [5 rows x 39 columns]

# %%
g_to_csv.describe()
# Out:
#        pubgardn         segid
# count   15234.0  15234.000000
# mean        1.0  45741.802613
# std         0.0  26046.356866
# min         1.0     47.000000
# 25%         1.0  22553.250000
# 50%         1.0  46526.500000
# 75%         1.0  67904.250000
# max         1.0  91650.000000

# %%
g_to_csv.to_csv("joined_pubgardn.csv",index=False,sep=',')

# %% [markdown]
# # Apply on other features - abandoned buildings / lots

# %%
abandon,abandon_to_csv = merge_feature_buffer(feature_file = 'Vacant_Area_containing_no_structures.shp',\
                                            df = segs,crs = '2263',sop_var_name = 'abndbldg')



abandon.head()
# Out:
#       SOURCE_ID  FEATURE_CO  SUB_FEATUR  NAME STATUS  \
# 0  2.125200e+10        2520      252000  None    New
# 0  2.125200e+10        2520      252000  None    New
# 0  2.125200e+10        2520      252000  None    New
# 0  2.125200e+10        2520      252000  None    New
# 0  2.125200e+10        2520      252000  None    New
#
#                                             geometry  index_right access  \
# 0  POLYGON ((988543.9196181768 193399.1263181274,...      35022.0   None
# 0  POLYGON ((988543.9196181768 193399.1263181274,...      35035.0   None
# 0  POLYGON ((988543.9196181768 193399.1263181274,...      23164.0   None
# 0  POLYGON ((988543.9196181768 193399.1263181274,...      35036.0   None
# 0  POLYGON ((988543.9196181768 193399.1263181274,...      41435.0   None
#
#   bridge        from  ...  RBlockFace FIRST_Traf MAX_Number MAX_Numb_1  \
# 0   None  1258875733  ...  0212260077          A          3          1
# 0   None    42492524  ...  0212260543          W          1          1
# 0   None   598043789  ...  0212261785          A          1          2
# 0   None  2406325294  ...  0212262092          W          3          1
# 0   None    42497734  ...  0212261615          W          1          2
#
#   MAX_Numb_2 MAX_POSTED FIRST_Bike                 FIRST_Stre MAX_Street  \
# 0          4         25       None  FLATBUSH AVENUE EXTENSION       44.0
# 0          2         25       None            CATHEDRAL PLACE       18.0
# 0          3         25       None            DUFFIELD STREET       30.0
# 0          4         25       None  FLATBUSH AVENUE EXTENSION       42.0
# 0          3         25       None              CHAPEL STREET       18.0
#
#   MIN_Street
# 0       42.0
# 0       18.0
# 0       30.0
# 0       42.0
# 0       18.0
#
# [5 rows x 36 columns]

# %%
abandon_to_csv.describe()
# Out:
#        abndbldg         segid
# count   21275.0  21275.000000
# mean        1.0  44372.215229
# std         0.0  26587.499703
# min         1.0     38.000000
# 25%         1.0  21452.500000
# 50%         1.0  42556.000000
# 75%         1.0  67748.000000
# max         1.0  91658.000000

# %%
abandon_to_csv.to_csv("joined_abndbldg.csv",index=False,sep=',')

# %% [markdown]
# # Apply on other features - other recreational area

# %%
r,r_to_csv = merge_feature_buffer(feature_file = 'Recreational_area__Not_NYC_designated_parks_.shp',\
                                            df = segs,crs = '2263',sop_var_name = 'pbspothr')


r.head()
# Out:
#       SOURCE_ID  FEATURE_CO  SUB_FEATUR  NAME   STATUS  \
# 0  2.125000e+10        2510      251000  None  Updated
# 0  2.125000e+10        2510      251000  None  Updated
# 0  2.125000e+10        2510      251000  None  Updated
# 0  2.125000e+10        2510      251000  None  Updated
# 2  2.125100e+10        2510      251000  None  Updated
#
#                                             geometry  index_right access  \
# 0  POLYGON ((989555.2816394208 191114.6564644873,...       5338.0   None
# 0  POLYGON ((989555.2816394208 191114.6564644873,...       5337.0   None
# 0  POLYGON ((989555.2816394208 191114.6564644873,...       5339.0   None
# 0  POLYGON ((989555.2816394208 191114.6564644873,...       5331.0   None
# 2  POLYGON ((988969.0772685393 194857.5632657198,...      46382.0   None
#
#   bridge      from  ...  RBlockFace FIRST_Traf MAX_Number MAX_Numb_1  \
# 0   None  42470439  ...  1922602879          T          2          2
# 0   None  42470437  ...  0212261337          A          1          2
# 0   None  42470437  ...  1922611951          A          1          2
# 0   None  42470437  ...  1922611035          T          2          2
# 2   None  42521949  ...  0212261565          A          2          1
#
#   MAX_Numb_2 MAX_POSTED FIRST_Bike         FIRST_Stre MAX_Street MIN_Street
# 0          4         25          2      ASHLAND PLACE       54.0       54.0
# 0          3         25       None  WILLOUGHBY STREET       30.0       30.0
# 0          3         25       None  ST EDWARDS STREET       34.0       30.0
# 0          4         25          2      ASHLAND PLACE       55.0       54.0
# 2          3         25       None        GOLD STREET       28.0       28.0
#
# [5 rows x 36 columns]

# %%
r_to_csv['pbspothr'].value_counts()
# Out:
# 1    14965
# Name: pbspothr, dtype: int64

# %%
r_to_csv.to_csv("joined_pbspothr.csv",index=False,sep=',')

# %%
r_to_csv.describe()
# Out:
#        pbspothr         segid
# count   14965.0  14965.000000
# mean        1.0  44867.262412
# std         0.0  26482.740971
# min         1.0      5.000000
# 25%         1.0  21909.000000
# 50%         1.0  43912.000000
# 75%         1.0  67990.000000
# max         1.0  91642.000000

# %%
r_to_csv.to_csv("joined_pbspothr.csv",index=False,sep=',')

# %% [markdown]
# # Apply on other features - beach

# %%
b,b_to_csv = merge_feature_buffer(feature_file = 'Boardwalk_along_beach.shp',\
                                            df = segs,crs = '2263',sop_var_name = 'beach')



b.head()
# Out:
#       SOURCE_ID  FEATURE_CO  SUB_FEATUR   STATUS  \
# 0  2.143000e+10        4300      430000  Updated
# 0  2.143000e+10        4300      430000  Updated
# 0  2.143000e+10        4300      430000  Updated
# 0  2.143000e+10        4300      430000  Updated
# 0  2.143000e+10        4300      430000  Updated
#
#                                             geometry  index_right access  \
# 0  POLYGON ((985072.5453808781 194857.5544855774,...       3383.0   None
# 0  POLYGON ((985072.5453808781 194857.5544855774,...      27353.0   None
# 0  POLYGON ((985072.5453808781 194857.5544855774,...       3385.0   None
# 0  POLYGON ((985072.5453808781 194857.5544855774,...       3384.0   None
# 0  POLYGON ((985072.5453808781 194857.5544855774,...       3394.0   None
#
#   bridge        from      highway  ...  RBlockFace FIRST_Traf MAX_Number  \
# 0   None  3174844141  residential  ...  0212261723          W          2
# 0   None  3174844147    secondary  ...  0212261723          T          2
# 0   None    42469320    secondary  ...  0212261723          T          2
# 0   None    42469325  residential  ...  0212260072          A          2
# 0   None   214362644  residential  ...  0212260072          A          2
#
#   MAX_Numb_1 MAX_Numb_2 MAX_POSTED FIRST_Bike         FIRST_Stre MAX_Street  \
# 0          1          3         25          2  OLD FULTON STREET       30.0
# 0          2          4         25          2  OLD FULTON STREET       66.0
# 0          2          4         25          2  OLD FULTON STREET       66.0
# 0          2          4         25       None       WATER STREET       42.0
# 0          2          4         25       None       WATER STREET       42.0
#
#   MIN_Street
# 0       28.0
# 0       58.0
# 0       58.0
# 0       24.0
# 0       24.0
#
# [5 rows x 35 columns]

# %%
b_to_csv.describe()
# Out:
#        beach         segid
# count  938.0    938.000000
# mean     1.0  51113.066098
# std      0.0  24571.535651
# min      1.0    470.000000
# 25%      1.0  29303.250000
# 50%      1.0  57583.500000
# 75%      1.0  70638.500000
# max      1.0  91479.000000

# %%
b_to_csv.to_csv("joined_beach.csv",index=False,sep=',')

# %%
parkinglot, parkinglot_2000 = merge_feature(feature_file = 'Parking_Lots___2000_Square_Feet.shp',\
                                            df = segs,crs = '2263',sop_var_name = 'surfpkng')
parkinglot.head()
# Out:
#       SOURCE_ID  FEATURE_CO  SUB_FEATUR     STATUS  \
# 0  2.150000e+10        5000      500000  Unchanged
# 1  2.150000e+10        5000      500000    Updated
# 2  2.150000e+10        5000      500000  Unchanged
# 3  2.150000e+10        5000      500000  Unchanged
# 4  2.150000e+10        5000      500000  Unchanged
#
#                                             geometry  \
# 0  POLYGON ((990044.4431236684 190843.5957248956,...
# 1  POLYGON ((989953.2139754146 191814.4684550613,...
# 2  POLYGON ((988897.051389575 195330.5549268126, ...
# 3  POLYGON ((989270.8839752525 195436.5458565652,...
# 4  POLYGON ((988145.6890471578 195152.533957392, ...
#
#                                       centroid  segid
# 0  POINT (990029.3636842157 190739.7197202197)   5339
# 1  POINT (989730.7282890398 191626.4517265979)   5338
# 2  POINT (988847.3157554124 195306.7784605023)   3452
# 3  POINT (989229.8061570526 195424.2433645794)   3455
# 4  POINT (988214.4357064107 195019.9356224579)  23148

# %%
parkinglot['area'] = parkinglot['geometry'].area/1e3
parkinglot['area'].describe()
# Out:
# count    20714.000000
# mean        18.235920
# std         53.228173
# min          1.157810
# 25%          4.537563
# 50%          7.663889
# 75%         14.900737
# max       2687.128727
# Name: area, dtype: float64

# %%
parkinglot_2000.head()
# Out:
#    surfpkng  segid
# 0         1      5
# 1         2     16
# 2         3     17
# 3         2     24
# 4         1     26

# %%
parkinglot_to_csv = parkinglot[['segid','area']].groupby('segid').mean().reset_index(level=0, drop=False)[['area','segid']]
    
#dt_to_csv.rename(columns = {'area':sop_var_name},inplace =True)

# %%
parkinglot_to_csv.head()
# Out:
#         area  segid
# 0   2.473414      5
# 1   5.782181     16
# 2  10.534842     17
# 3   4.151009     24
# 4  11.838975     26

# %%
parkinglot_to_csv.area.describe()
# Out:
# count    13006.000000
# mean        16.410941
# std         41.928176
# min          1.283689
# 25%          4.780216
# 50%          7.835768
# 75%         14.655558
# max       2687.128727
# Name: area, dtype: float64

# %%
parkinglot_to_csv.shape
# Out:
# (13006, 2)

# %%
parkinglot_to_csv['sizeparkimi2'] = parkinglot_to_csv['area']
for i in range(parkinglot_to_csv.shape[0]):
    area = parkinglot_to_csv.loc[i, 'area']
    if area>=14.655558:
        parkinglot_to_csv.loc[i, 'sizeparkimi2'] = 4
    elif area>=7.835768:
        parkinglot_to_csv.loc[i, 'sizeparkimi2'] = 3
    elif area>=7.835768:
        parkinglot_to_csv.loc[i, 'sizeparkimi2'] = 2
    else:
        parkinglot_to_csv.loc[i, 'sizeparkimi2'] = 1
parkinglot_to_csv['sizeparkimi2'].describe()
# Out:
# count    13006.000000
# mean         2.250038
# std          1.299125
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.750000
# max          4.000000
# Name: sizeparkimi2, dtype: float64

# %%
parkinglot_to_csv = parkinglot_to_csv[['segid', 'sizeparkimi2']]
parkinglot_to_csv.head()
# Out:
#    segid  sizeparkimi2
# 0      5           1.0
# 1     16           1.0
# 2     17           3.0
# 3     24           1.0
# 4     26           3.0

# %%
parkinglot_to_csv.to_csv("joined_parkinglot_2000.csv",index=False,sep=',')
